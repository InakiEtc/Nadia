# %%
import pandas as pd
import seaborn as sb

data = pd.read_csv("../data/demandaElectricidadMensuales.csv",sep=",",engine="python")

grafico = sb.pairplot(data,hue="indice_tiempo",palette="Spectral")

# %%
grafico = sb.pairplot(data, hue="demanda_total",palette="icefire")

# %%
grafico = sb.pairplot(data,hue="temperatura_promedio",palette="coolwarm")

# %%
data2 = data[["indice_tiempo","demanda_total","temperatura_promedio"]]
grafico = sb.pairplot(data2, hue="indice_tiempo",palette="icefire")

# %% [markdown]
# ## Conclusiones
