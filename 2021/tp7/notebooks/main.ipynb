# %%
import pandas as pd
import seaborn as sb

data = pd.read_csv("../data/demandaElectricidadMensuales.csv",sep=",",engine="python")

grafico = sb.pairplot(data,hue="indice_tiempo",palette="icefire")

# %% [markdown]
# ## Conclusiones
