# %%
import pandas as pd
import matplotlib.pyplot as gf1
import matplotlib.pyplot as gf2
import numpy as np

data = pd.read_csv("../data/llamados-atendidos-violencia-familiar-202105.csv")
data = data.loc[0:100]

# %%
x = data['violencia_tipo'].unique()
y = data['violencia_tipo'].value_counts().tolist()
y.reverse()

gf1.bar(x,y)
gf1.title('Tipos de violencia')
gf1.xlabel('Tipos de Violencia')
gf1.ylabel('cantidad de Violencias')
gf1.xticks(rotation=90,fontsize=11)
gf1.show()

# %%
xx = data['agresor_relacion_victima'].unique()
yy = data['agresor_relacion_victima'].value_counts().tolist()
yy.reverse()

gf2.plot(xx, yy)
gf2.title('Relacion Victima-Agresor')
gf2.xlabel('Relacion')
gf2.ylabel('Cantidad')
gf2.xticks(rotation=90,fontsize=11)
gf2.show()

# %% [markdown]
# ### Respuestas:
#
# 1. Cuando se trata de violencia familiar suele haber mas de un tipo de violencia, es decir, es mas probable que se agreda de 2 o mas formas.
# 2. Si bien la edad de la victima en casos aparece, en gran parte no aparece ya que estas llamadas pueden ser anonimas.
# 3. Viendo que  mayormente el agresor es un padrastro y que se aplica violencia Fisica, sexual y psicologica, se podria llegar a pensar que, claramente la victima es mujer, y que se llego a la violencia por una pelea entre agresor y victima o que se llego por problemas con la madre de la victima.
