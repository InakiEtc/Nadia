# %%
import requests
import json

archivo = open("playlist.csv", "w")
nombres_columnas = "mensaje , status \n"
archivo.write(nombres_columnas)
urlStats = "https://api.spotify.com/v1/playlists/5XZ38MyD1GxLSUuEAZOLRc"
headersToken = {"Authorization": "Bearer BQAVmUcGMDfT2ob9uETspP22arPa-goTv8yrXiZl4eEmnZYPbdEYRrck_Dwk3UejBnAzHDlSsmapBOcT4krE6WhqzcBcQUi3j-zZpdozZyvlxv2VmJR0lX8w0qs8Vu4W7rTBewddVvuNUYgz"}
res = requests.get(url=urlStats, headers=headersToken)

print(json.dumps(res.json()["tracks"]["items"], indent=2))
# Out:
# [
#   {
#     "added_at": "2020-05-07T19:08:03Z",
#     "added_by": {
#       "external_urls": {
#         "spotify": "https://open.spotify.com/user/11139535378"
#       },
#       "href": "https://api.spotify.com/v1/users/11139535378",
#       "id": "11139535378",
#       "type": "user",
#       "uri": "spotify:user:11139535378"
#     },
#     "is_local": false,
#     "primary_color": null,
#     "track": {
#       "album": {
#         "album_type": "single",
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/1i8SpTcr7yvPOmcqrbnVXY"
#             },
#             "href": "https://api.spotify.com/v1/artists/1i8SpTcr7yvPOmcqrbnVXY",
#             "id": "1i8SpTcr7yvPOmcqrbnVXY",
#             "name": "Ozuna",
#             "type": "artist",
#             "uri": "spotify:artist:1i8SpTcr7yvPOmcqrbnVXY"
#           },
#           {
#             "external_urls": {
# ...
