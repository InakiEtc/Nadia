# %%
import pandas as pd
import seaborn as sb

data = pd.read_csv("../data/oficina-rescate-denuncias.csv",sep=",",engine="python")
data1 = data[["es_anonima","denunciante_edad_aparente","hora_ingreso"]]
grafico = sb.pairplot(data,hue="es_anonima",palette="icefire")

# %% [markdown]
# El dataset trata de las llamadas al 145 por trata de personas,
# como se puede ver en el graffico de abajo a la izquierda
# la mayoria de las llamadas no son anonimas y suelen ser
# de personas mayores a 20 años (suelen ser de 50 años mas o menos)
# y estas llamadas suelen ser la mayoria de buenos aires que
# su ID de provincia es el 6 y como se ve en uno de los graficos
# la punta esta mas cerca del 0 y por lo general en BSAS las
# no suelen ser anonimas(como la mayoria)
